# %%
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()
import numpy as np
import os
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib import rcParams
import sys
import pickle
from functools import partial
 
plt.rcParams.update({'font.size': 16,                                                                                                                                                    
                     'axes.labelsize': 16, 'legend.fontsize': 12, 
                     'xtick.labelsize': 16, 'ytick.labelsize': 16, 'axes.titlesize': 16,
                     'axes.linewidth': 1.5}) 

print(tf.__version__)
# Out:
# 2.2.0

# %%
import pae.load_data as ld
load_funcs=dict(mnist=ld.load_mnist, fmnist=ld.load_fmnist, celeba=ld.load_celeba)

# %%
from pae.fid_score_tf2 import *

# %%
PROJECT_PATH = "../../" 
PARAMS_PATH  = os.path.join(PROJECT_PATH,'params')
param_file   = 'params_fmnist_-1_40_infoGAN_VAE_best_params_noaugment_no_dropout_flow_prior_full_sigmaVAE_beta1'
params       = pickle.load(open(os.path.join(PARAMS_PATH,param_file+'.pkl'),'rb'))

# %%
LOCAL = '/global/homes/v/vboehm/codes/PAE'

# %%
params['plot_dir'] = os.path.join(LOCAL,'plots',params['label'])
pickle.dump(params, open(os.path.join(PARAMS_PATH,param_file+'.pkl'),'wb'))

# %%
print(params['plot_dir'], params['module_dir'])
# Out:
# /global/homes/v/vboehm/codes/PAE/plots/fmnist/class-1/latent_size40/net_type_infoGAN/loss_VAE/best_params_noaugment_no_dropout_flow_prior_full_sigmaVAE_beta1 /global/cscratch1/sd/vboehm/RNF/modules/fmnist/class-1/latent_size40/net_type_infoGAN/loss_VAE/best_params_noaugment_no_dropout_flow_prior_full_sigmaVAE_beta1

# %%
if not os.path.isdir(params['plot_dir']):
    os.makedirs(params['plot_dir'])
# if not os.path.isdir(params['data_dir']):
#     os.makedirs(params['data_dir'])

# %%
load_func                                          = load_funcs[params['data_set']]
x_train, y_train, x_valid, y_valid, x_test, y_test = load_func(params['data_dir'])

if np.all(x_test)==None:
    x_test=x_valid

x_train    = x_train/255.-0.5
x_test     = x_test/255.-0.5
x_valid    = x_valid/255.-0.5

# %%
generator_path   = os.path.join(params['module_dir'],'decoder')
encoder_path     = os.path.join(params['module_dir'],'encoder')
nvp_path         = os.path.join(params['module_dir'],'flow')

# %%
shape = params['data_shape']
shape = np.append(-1,shape)
print(shape)

x_valid = np.reshape(x_valid, shape)
# Out:
# [-1 28 28  1]

# %%
import tensorflow.compat.v1 as tf
import tensorflow_probability as tfp
import tensorflow_hub as hub
tfd = tfp.distributions
tfb = tfp.bijectors

# %%
tf.reset_default_graph()

data          = tf.placeholder(shape=[None]+params['data_shape'],dtype=tf.float32)
latent_point  = tf.placeholder(shape=[None,params['latent_size']],dtype=tf.float32)
u_enc         = tf.placeholder(shape=[None,params['latent_size']],dtype=tf.float32)
sample_size   = tf.placeholder_with_default(params['batch_size'], shape=[])
encoder       = hub.Module(encoder_path, trainable=False)
decoder       = hub.Module(generator_path, trainable=False)
nvp           = hub.Module(nvp_path, trainable=False)
prior         = tfd.MultivariateNormalDiag(tf.zeros(params['latent_size']), scale_identity_multiplier=1.0)

encoded, _    = tf.split(encoder({'x':data},as_dict=True)['z'], 2, axis=-1)
decoded       = decoder({'z':encoded},as_dict=True)['x']

decoded_latent= decoder({'z':latent_point},as_dict=True)['x']

sigma         = tf.reduce_mean(tf.sqrt(tf.square(data-decoded)),axis=0)

samples         = prior.sample(sample_size)
decoded_samples = decoder({'z':samples},as_dict=True)['x']
nvp_samples     = nvp({'z_sample':np.zeros((1,params['latent_size'])),'sample_size':1, 'u_sample':samples}, as_dict=True)['fwd_pass']
u_samples       = nvp({'z_sample':encoded,'sample_size':1, 'u_sample':samples}, as_dict=True)['bwd_pass']
z_samples       = nvp({'z_sample':encoded,'sample_size':1, 'u_sample':u_enc}, as_dict=True)['fwd_pass']
decoded_nvp_samples = decoder({'z':nvp_samples},as_dict=True)['x']
decoded_samples = decoder({'z':z_samples},as_dict=True)['x']
# Out:
# WARNING:tensorflow:From /global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/site-packages/tensorflow_probability/python/distributions/distribution.py:332: calling MultivariateNormalDiag.__init__ (from tensorflow_probability.python.distributions.mvn_diag) with scale_identity_multiplier is deprecated and will be removed after 2020-01-01.
# Instructions for updating:
# `scale_identity_multiplier` is deprecated; please combine it with `scale_diag` directly instead.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.neighbors import KDTree

np.random.seed(45026)

random_nvp_samples=[]
for ii in range(10000//params['batch_size']+1):
    random_nvp_samples+=[sess.run(decoded_nvp_samples)]
random_nvp_samples=np.asarray(random_nvp_samples).reshape((-1,28,28))[0:10000]

u_encoded_train = []
x_train = x_train.reshape((-1,28,28,1))
for ii in range(60000//params['batch_size']):
    u_encoded_train+=[sess.run(u_samples, feed_dict={data:x_train[ii*params['batch_size']:(ii+1)*params['batch_size']]})]
u_encoded_train   = np.asarray(u_encoded_train).reshape((-1,40))
u_encoded_samples = sess.run(u_samples, feed_dict={data:np.expand_dims(random_nvp_samples[0:params['batch_size']],-1)})

kdt = KDTree(u_encoded_train, leaf_size=10, metric='manhattan')
nns = kdt.query(u_encoded_samples, k=1, return_distance=True)

train_fwd = sess.run(decoded_samples, feed_dict={u_enc:np.squeeze(u_encoded_train[nns[1]])})

plt.scatter(u_encoded_train[nns[1]][0],u_encoded_train[nns[1]][1])
plt.scatter(u_encoded_samples[0],u_encoded_samples[1])

nns = np.squeeze(nns[1])

plt.figure(figsize=(6,6))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.05, hspace=0.05)
for ii in range(25):
    plt.subplot(5,5,ii+1)
    plt.imshow(np.squeeze((random_nvp_samples[ii]+0.5).reshape(shape)),cmap='gray',vmin=0, vmax=1)
    plt.axis('off')
plt.savefig(os.path.join(params['plot_dir'],'nvp_samples_for_nns.pdf'),bbox_inches='tight')
plt.show()

plt.figure(figsize=(6,6))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.05, hspace=0.05)
for ii in range(25):
    plt.subplot(5,5,ii+1)
    plt.imshow(np.squeeze((train_fwd[ii]+0.5).reshape(shape)),cmap='gray',vmin=0, vmax=1)
    plt.axis('off')
plt.savefig(os.path.join(params['plot_dir'],'nvp_samples_nns_in_train_model.pdf'),bbox_inches='tight')
plt.show()

plt.figure(figsize=(6,6))
for ii in range(25):
    plt.subplot(5,5,ii+1)
    plt.imshow(np.squeeze((x_train[nns[ii]]+0.5).reshape(shape)),cmap='gray',vmin=0, vmax=1)
    plt.axis('off')
plt.savefig(os.path.join(params['plot_dir'],'nvp_samples_nns_in_train.pdf'),bbox_inches='tight')
plt.show()

# %%
rec, d            = sess.run([decoded,data], feed_dict={data:x_valid[0:params['batch_size']]})
recs=[]
delta = len(x_valid)%params['batch_size']
for ii in range(len(x_valid)//params['batch_size']):
    recs+=[sess.run(decoded, feed_dict={data:x_valid[ii*params['batch_size']:(ii+1)*params['batch_size']]})]
data_sample=np.concatenate((x_valid[(ii+1)*params['batch_size']:len(x_valid)],x_valid[0:params['batch_size']-delta]))
recs+=[sess.run(decoded, feed_dict={data:data_sample})]
recs = np.asarray(recs).reshape(shape)[0:len(x_valid)]

# %%
from sklearn.utils import resample

# %%
recon_diff = np.square(x_valid-recs)

index = np.argsort(np.mean(recon_diff,axis=(1,2,3)))

index = index[-25::]
#index = index[np.where(y_valid[index]==5)]
#index = index[-1000::]
print(y_valid[index])
print(len(index))
print(index[4])
#
jj=1
plt.figure(figsize=(5,5))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.05, hspace=0.05)
for ii in range(25):
    plt.subplot(5,5,ii+1)
    plt.imshow(np.squeeze((x_valid[index[ii]]+0.5)),cmap='gray',vmin=0, vmax=1)
    plt.axis('off')
plt.savefig(os.path.join(params['plot_dir'],'orig_valid_set_worse.pdf'),bbox_inches='tight')
plt.show()

plt.figure(figsize=(5,5))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.05, hspace=0.05)
for ii in range(25):
    plt.subplot(5,5,ii+1)
    plt.imshow(np.squeeze(recs[index[ii]]+0.5),cmap='gray',vmin=0, vmax=1)
    plt.axis('off')

plt.savefig(os.path.join(params['plot_dir'],'rec_valid_set_worse.pdf'),bbox_inches='tight')
plt.show()
# Out:
# [6 0 8 3 1 2 8 2 4 6 6 6 5 3 0 0 2 2 0 6 8 1 0 6 2]
# 25
# 3052

# %%
res =[]
res1=[]
res2=[]
for ii in range(1000):
    sample = resample(recon_diff, replace=True, n_samples=len(recon_diff))
    res.append(np.mean(sample))
    res1.append(np.percentile(a=sample.flatten(),q=68))
    res2.append(np.percentile(a=sample.flatten(),q=95))

# %%
print(np.mean(res),np.std(res),np.mean(res1),np.std(res1),np.mean(res2),np.std(res2))
# Out:
# 0.00659531581475327 6.412603344988879e-05 0.0011917601098601718 1.3574719157383085e-05 0.03191043766821199 0.0003491788747125577

# %%
full_sigma = np.sqrt(np.mean(np.square(x_valid-recs),axis=0))
mean_sigma = np.mean(np.square(x_valid-recs))
print(mean_sigma)
mean_var   = np.mean(full_sigma**2)
# plt.figure()
# plt.title('pixel-wise variance')
# plt.imshow((full_sigma**2).reshape([64,64,3]), cmap='gray')
# plt.colorbar()
# plt.axis('off')
# plt.savefig(os.path.join(params['plot_dir'],'measured_sigma.pdf'),bbox_inches='tight')
# plt.show()
params['full_sigma']=full_sigma
pickle.dump(params,open(os.path.join(PARAMS_PATH,param_file+'.pkl'),'wb'))
print('mean variance', mean_var)
print('minimum variance', np.min(full_sigma**2))
print('maximal variance', np.max(full_sigma**2))
# Out:
# 0.006594709790053544
# mean variance 0.006594709790053509
# minimum variance 7.22463719425977e-08
# maximal variance 0.01413138639988872

# %%
full_sigma.shape
# Out:
# (28, 28, 1)

# %%
_ = plt.hist(((x_valid-recs)**2).flatten(), density=True, bins=1000, cumulative=True, log=False)
plt.show()
print('mean',np.mean((x_valid-recs).flatten()**2))
print('68 and 95 percentiles:', np.percentile(a=(x_valid-recs).flatten()**2,q=68),np.percentile(a=(x_valid-recs).flatten()**2,q=95))
# Out:
# mean 0.007683500263402
# 68 and 95 percentiles: 0.0008713688633621047 0.03570510100475154

# %%
jj=1
plt.figure(figsize=(4,4))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.05, hspace=0.05)
for ii in range(16):
    plt.subplot(4,4,ii+1)
    plt.imshow(np.squeeze((d[ii]+0.5)),cmap='gray',vmin=0, vmax=1)
    plt.axis('off')
plt.savefig(os.path.join(params['plot_dir'],'orig_valid_set.pdf'),bbox_inches='tight')
plt.show()

plt.figure(figsize=(4,4))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.05, hspace=0.05)
for ii in range(16):
    plt.subplot(4,4,ii+1)
    plt.imshow(np.squeeze(rec[ii]+0.5),cmap='gray',vmin=0, vmax=1)
    plt.axis('off')

plt.savefig(os.path.join(params['plot_dir'],'rec_valid_set.pdf'),bbox_inches='tight')
plt.show()

# %%
random_samples=[]
for ii in range(10000//params['batch_size']+1):
    random_samples+=[sess.run(decoded_samples)]
random_samples=np.asarray(random_samples).reshape(shape)[0:10000]

plt.figure(figsize=(4,4))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.05, hspace=0.05)
for ii in range(16):
    plt.subplot(4,4,ii+1)
    plt.imshow(np.squeeze((random_samples[ii]+0.5)),cmap='gray',vmin=0, vmax=1)
    plt.axis('off')
#plt.savefig(os.path.join(params['plot_dir'],'raw_samples.pdf'),bbox_inches='tight')
plt.show()

# %%
random_nvp_samples=[]
for ii in range(10000//params['batch_size']+1):
    random_nvp_samples+=[sess.run(decoded_nvp_samples)]
random_nvp_samples=np.asarray(random_nvp_samples).reshape((-1,28,28))[0:10000]
plt.figure(figsize=(6,6))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.05, hspace=0.05)
for ii in range(25):
    plt.subplot(5,5,ii+1)
    plt.imshow(np.squeeze((random_nvp_samples[ii]+0.5).reshape(shape)),cmap='gray',vmin=0, vmax=1)
    plt.axis('off')
plt.savefig(os.path.join(params['plot_dir'],'nvp_samples.pdf'),bbox_inches='tight')
plt.show()

# %%
try:
    latent_point1 = sess.run(encoded, feed_dict={data:x_valid[0:params['batch_size']]})
    latent_point2 = sess.run(encoded, feed_dict={data:x_valid[1:params['batch_size']+1]})
except:
    latent_point1 = sess.run(encoded)
    latent_point2 = sess.run(encoded)    
#latent_point1, latent_point2 = pickle.load(open('latent_points_for_interpolation_celeba.pkl','rb'))
interp = latent_point1+(latent_point2-latent_point1)*np.arange(8)[:, None,None]/8.

decoded_interp=[]

for jj in range(min(params['batch_size'],16)):
    fig, ax = plt.subplots(1,8,figsize=(9,1))
    for ii in range(8):
        decoded_interp=sess.run(decoded_latent, feed_dict={latent_point:interp[ii]})[jj]
        ax[ii].imshow(np.squeeze(decoded_interp.reshape(shape))+0.5, vmin=0,vmax=1, cmap='gray')
        ax[ii].axis('off')
    #plt.tight_layout()
    plt.subplots_adjust(wspace=0, hspace=0)
    plt.savefig(os.path.join(params['plot_dir'],'interp%d.pdf'%jj),bbox_inches='tight')
    plt.show()

# %%
def evaluate_fid_score(fake_images, real_images,norm=True):
    #np.random.shuffle(real_images)
    assert(len(real_images))
    assert(len(fake_images))
    real_images = real_images[0:10000]
    fake_images = fake_images[0:10000]
    real_images = preprocess_fake_images(real_images, norm)
    fake_images = preprocess_fake_images(fake_images, norm)

    inception_path = check_or_download_inception()

    create_inception_graph(inception_path)
    sess = tf.InteractiveSession()
    sess.run(tf.global_variables_initializer())

    print('calculating tf features...')
    real_out = get_activations_tf(real_images, sess)
    fake_out = get_activations_tf(fake_images, sess)
    fid_result = fid_score(real_out, fake_out)
    sess.close()

    return fid_result

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sklearn
from sklearn.utils import resample

# %%
fid_scores_raw = []
for ii in range(20):
    print(ii)
    sample_1 = resample(random_samples,replace=True,n_samples=10000)
    sample_2 = resample(x_valid,replace=True,n_samples=10000)
    fid_scores_raw.append(evaluate_fid_score(sample_1,sample_2))
    print(np.mean(fid_scores_raw))
# Out:
# 0
# norm =  True
# norm =  True
# WARNING:tensorflow:From /global/u2/v/vboehm/codes/PAE/pae/fid_score_tf2.py:32: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# calculating tf features...
# 217.05852969320534
# 1
# norm =  True
# norm =  True
# calculating tf features...
# 217.2685196461842
# 2
# norm =  True
# norm =  True
# calculating tf features...
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-30-12fcffc9ea67>", line 6, in <module>
#     fid_scores_raw.append(evaluate_fid_score(sample_1,sample_2))
#   File "<ipython-input-27-9dcf59f121bd>", line 17, in evaluate_fid_score
#     real_out = get_activations_tf(real_images, sess)
#   File "/global/u2/v/vboehm/codes/PAE/pae/fid_score_tf2.py", line 111, in get_activations_tf
#     pred = sess.run(inception_layer, {'FID_Inception_Net/ExpandDims:0': batch})
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/site-packages/tensorflow/python/client/session.py", line 957, in run
#     result = self._run(None, fetches, feed_dict, options_ptr,
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/site-packages/tensorflow/python/client/session.py", line 1180, in _run
#     results = self._do_run(handle, final_targets, final_fetches,
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/site-packages/tensorflow/python/client/session.py", line 1358, in _do_run
#     return self._do_call(_run_fn, feeds, fetches, targets, options,
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/site-packages/tensorflow/python/client/session.py", line 1365, in _do_call
#     return fn(*args)
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/site-packages/tensorflow/python/client/session.py", line 1349, in _run_fn
#     return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/site-packages/tensorflow/python/client/session.py", line 1441, in _call_tf_sessionrun
#     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1148, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/posixpath.py", line 391, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/posixpath.py", line 425, in _joinrealpath
#     if not islink(newpath):
#   File "/global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/posixpath.py", line 167, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
fid_scores_raw=np.asarray(fid_scores_raw)
_ = plt.hist(fid_scores_raw, density=True, bins=100)
print(np.mean(fid_scores_raw),np.percentile(fid_scores_raw,68),np.percentile(fid_scores_raw,95))
# Out:
# 217.2685196461842 217.34411602925658 217.45751060386516

# %%
fid_scores_rec = []
for ii in range(50):
    print(ii)
    sample_1 = resample(recs,replace=True,n_samples=10000)
    sample_2 = resample(x_valid,replace=True,n_samples=10000)
    fid_scores_rec.append(evaluate_fid_score(sample_1,sample_2))
    print(np.mean(fid_scores_rec))
    
fid_scores_rec=np.asarray(fid_scores_rec)
_ = plt.hist(fid_scores_rec, density=True, bins=100)
print(np.mean(fid_scores_rec),np.percentile(fid_scores_rec,68),np.percentile(fid_scores_rec,95))
# Out:
# 0
# norm =  True
# norm =  True
# WARNING:tensorflow:From /global/u2/v/vboehm/codes/PAE/pae/fid_score_tf2.py:32: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# calculating tf features...
# 30.92608467172451
# 1
# norm =  True
# norm =  True
# calculating tf features...
# 31.248242234540186
# 2
# norm =  True
# norm =  True
# calculating tf features...
# 31.391630237028824
# 3
# norm =  True
# norm =  True
# calculating tf features...
# 31.461883815173465
# 4
# norm =  True
# norm =  True
# calculating tf features...
# 31.50093137403848
# 5
# norm =  True
# norm =  True
# calculating tf features...
# 31.350959191093807
# 6
# norm =  True
# norm =  True
# calculating tf features...
# 31.37853523011335
# 7
# norm =  True
# norm =  True
# calculating tf features...
# 31.393179019400716
# 8
# norm =  True
# norm =  True
# calculating tf features...
# 31.355734589057324
# 9
# norm =  True
# norm =  True
# calculating tf features...
# 31.348815322215152
# 10
# norm =  True
# norm =  True
# calculating tf features...
# 31.31788306776067
# 11
# norm =  True
# norm =  True
# calculating tf features...
# 31.32945396333184
# 12
# norm =  True
# norm =  True
# calculating tf features...
# 31.333511429378557
# 13
# norm =  True
# norm =  True
# calculating tf features...
# 31.326731817448003
# 14
# norm =  True
# norm =  True
# calculating tf features...
# 31.306054662180795
# 15
# norm =  True
# norm =  True
# calculating tf features...
# 31.318111678143634
# 16
# norm =  True
# norm =  True
# calculating tf features...
# 31.291487300496875
# 17
# norm =  True
# norm =  True
# calculating tf features...
# 31.3033348260233
# 18
# norm =  True
# norm =  True
# calculating tf features...
# 31.296970975294062
# 19
# norm =  True
# norm =  True
# calculating tf features...
# 31.28751358719
# 20
# norm =  True
# norm =  True
# calculating tf features...
# 31.26284345696945
# 21
# norm =  True
# norm =  True
# calculating tf features...
# 31.25532356572825
# 22
# norm =  True
# norm =  True
# calculating tf features...
# 31.25019629020663
# 23
# norm =  True
# norm =  True
# calculating tf features...
# 31.255937812682372
# 24
# norm =  True
# norm =  True
# calculating tf features...
# 31.254594268254124
# 25
# norm =  True
# norm =  True
# calculating tf features...
# 31.249750418386125
# 26
# norm =  True
# norm =  True
# calculating tf features...
# 31.24737748806661
# 27
# norm =  True
# norm =  True
# calculating tf features...
# 31.24951100132655
# 28
# norm =  True
# norm =  True
# calculating tf features...
# 31.238919076403377
# 29
# norm =  True
# norm =  True
# calculating tf features...
# 31.25867486572503
# 30
# norm =  True
# norm =  True
# calculating tf features...
# 31.259248348513225
# 31
# norm =  True
# norm =  True
# calculating tf features...
# 31.263120263900426
# 32
# norm =  True
# norm =  True
# calculating tf features...
# 31.24836237074232
# 33
# norm =  True
# norm =  True
# calculating tf features...
# 31.254643981683156
# 34
# norm =  True
# norm =  True
# calculating tf features...
# 31.245223384802465
# 35
# norm =  True
# norm =  True
# calculating tf features...
# 31.23381979399811
# 36
# norm =  True
# norm =  True
# calculating tf features...
# 31.23493844170142
# 37
# norm =  True
# norm =  True
# calculating tf features...
# 31.22845934711905
# 38
# norm =  True
# norm =  True
# calculating tf features...
# 31.234011795799834
# 39
# norm =  True
# norm =  True
# calculating tf features...
# 31.243277760030544
# 40
# norm =  True
# norm =  True
# calculating tf features...
# 31.223872625194733
# 41
# norm =  True
# norm =  True
# calculating tf features...
# 31.217508571378463
# 42
# norm =  True
# norm =  True
# calculating tf features...
# 31.217019574493342
# 43
# norm =  True
# norm =  True
# calculating tf features...
# 31.23563106591239
# 44
# norm =  True
# norm =  True
# calculating tf features...
# 31.25848960809404
# 45
# norm =  True
# norm =  True
# calculating tf features...
# 31.250950009315762
# 46
# norm =  True
# norm =  True
# calculating tf features...
# 31.246335338644904
# 47
# norm =  True
# norm =  True
# calculating tf features...
# 31.241283782631246
# 48
# norm =  True
# norm =  True
# calculating tf features...
# 31.241660572466547
# 49
# norm =  True
# norm =  True
# calculating tf features...
# 31.251048058953135
# 31.251048058953135 31.406236674758986 31.777341719387287

# %%
np.std(fid_scores_rec)
# Out:
# 0.35124840198055163

# %%
fid_scores_nvp = []
for ii in range(20):
    print(ii)
    sample_1 = resample(np.expand_dims(random_nvp_samples,-1),replace=True,n_samples=10000)
    sample_2 = resample(x_valid,replace=True,n_samples=10000)
    fid_scores_nvp.append(evaluate_fid_score(sample_1,sample_2))
    print(np.mean(fid_scores_nvp))
    
fid_scores_nvp=np.asarray(fid_scores_nvp)
_ = plt.hist(fid_scores_nvp, density=True, bins=100)
print(np.mean(fid_scores_nvp),np.percentile(fid_scores_nvp,68),np.percentile(fid_scores_nvp,95))
# Out:
# 0
# norm =  True
# norm =  True
# calculating tf features...
# 23.47883973569563
# 1
# norm =  True
# norm =  True
# calculating tf features...
# 23.476184151196115
# 2
# norm =  True
# norm =  True
# calculating tf features...
# 23.682673036925408
# 3
# norm =  True
# norm =  True
# calculating tf features...
# 23.706740514477566
# 4
# norm =  True
# norm =  True
# calculating tf features...
# 23.72267340633358
# 5
# norm =  True
# norm =  True
# calculating tf features...
# 23.74481686310152
# 6
# norm =  True
# norm =  True
# calculating tf features...
# 23.745985807720746
# 7
# norm =  True
# norm =  True
# calculating tf features...
# 23.781224493097955
# 8
# norm =  True
# norm =  True
# calculating tf features...
# 23.777170837341444
# 9
# norm =  True
# norm =  True
# calculating tf features...
# 23.759589130654653
# 10
# norm =  True
# norm =  True
# calculating tf features...
# 23.7448384195693
# 11
# norm =  True
# norm =  True
# calculating tf features...
# 23.6896252843995
# 12
# norm =  True
# norm =  True
# calculating tf features...
# 23.678349583321513
# 13
# norm =  True
# norm =  True
# calculating tf features...
# 23.655402621199187
# 14
# norm =  True
# norm =  True
# calculating tf features...
# 23.660403768839263
# 15
# norm =  True
# norm =  True
# calculating tf features...
# 23.65282964152854
# 16
# norm =  True
# norm =  True
# calculating tf features...
# 23.62616591467625
# 17
# norm =  True
# norm =  True
# calculating tf features...
# 23.594581757676462
# 18
# norm =  True
# norm =  True
# calculating tf features...
# 23.602366182196132
# 19
# norm =  True
# norm =  True
# calculating tf features...
# 23.573817906261688
# 23.573817906261688 23.7445611298702 24.031283066620713

# %%
np.std(fid_scores_nvp), np.std(fid_scores_rec)
# Out:
# (0.2975953952881022, 0.324422996851694)

# %%
for ii in range(20):
    plt.scatter(ii, np.mean(fid_scores_nvp[:ii]))
plt.show()
for ii in range(20):
    plt.scatter(ii, np.std(fid_scores_nvp[:ii]))

# %%
for ii in range(20):
    plt.scatter(ii, np.mean(fid_scores_rec[:ii]))
plt.show()
for ii in range(20):
    plt.scatter(ii, np.std(fid_scores_rec[:ii]))
